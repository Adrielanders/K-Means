# %%
# K-Means Clustering

# Importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('C:\\Users\\Adriel\\Downloads\\Mall_Customers.csv')
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#Importing the mall dataset with pandas
A = dataset.iloc[:,[3,4]].values

# %%
# Using the elbow method to find the optimal number of clusters

from sklearn.cluster import KMeans
wcss =[]
for i in range (1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter =300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
# Plot the graph to visualize the Elbow Method to find the optimal number of cluster  
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Applying KMeans to the dataset with the optimal number of cluster

kmeans=KMeans(n_clusters= 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
B_Kmeans = kmeans.fit_predict(A)

# %%
# Visualising the clusters

plt.scatter(A[B_Kmeans == 0, 0], A[B_Kmeans == 0,1],s = 100, c='red', label = 'Clustering 1')

plt.scatter(A[B_Kmeans == 1, 0], A[B_Kmeans == 1,1],s = 100, c='blue', label = 'Clustering 2')

plt.scatter(A[B_Kmeans == 2, 0], A[B_Kmeans == 2,1],s = 100, c='green', label = 'Clustering 3')

plt.scatter(A[B_Kmeans == 3, 0], A[Y_Kmeans == 3,1],s = 100, c='cyan', label = 'Clustering 4')

plt.scatter(A[B_Kmeans == 4, 0], A[Y_Kmeans == 4,1],s = 100, c='magenta', label = 'Clustering 5')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s = 250, c = 'yellow', label = 'Centroids')
    
plt.title('Clusters of clients')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending score (1-100)')
plt.legend()
plt.show()
